# %% [markdown]
# <a href="https://colab.research.google.com/github/Weddy93/AI-for-software-engineering/blob/main/predictive_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
import os
from PIL import Image
from pathlib import Path
def read_image_metadata_to_dataframe("C:\\Users\\Administrator\\Downloads\\iuss-23-24-automatic-diagnosis-breast-cancer"):

    metadata_list = []

    for file_path in Path("C:\\Users\\Administrator\\Downloads\\iuss-23-24-automatic-diagnosis-breast-cancer") .glob('*.*'):
        if file_path.suffix.lower() in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
            try:
                with Image.open(file_path) as img:
                    metadata = {
                        'filename': file_path.name,
                        'file_path': str(file_path),
                        'file_size': file_path.stat().st_size,
                        'width': img.width,
                        'height': img.height,
                        'format': img.format,
                        'mode': img.mode,
                        'aspect_ratio': img.width / img.height if img.height > 0 else 0
                    }
                    metadata_list.append(metadata)

            except Exception as e:
                print(f"Error reading {"C:\\Users\\Administrator\\Downloads\\iuss-23-24-automatic-diagnosis-breast-cancer"}: {str(e)}")

    return pd.DataFrame(metadata_list)

# Usage
metadata_df = read_image_metadata_to_dataframe("path/to/images")
print(metadata_df.describe())
# preprocessing data
# cleaning data
df.dropna(inplace=True)
# checking for missing values
print(df.isnull().sum())
# labeling the data
x = df.drop(columns=['priority'])
y = df['priority']
# splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# training the model
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
# evaluating the model
accuracy = model.score(x_test, y_test)
print("model accuracy:", accuracy)
# predicting on test set for F1-score
y_pred = model.predict(y_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print("model F1-score:", f1)
